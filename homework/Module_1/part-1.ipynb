# %% [markdown]
# # Homework Part 1
#
# - Basically using MCP tool to replicate agent-like workflow.
# - Use Model Context Protocal Tools + Claude Desktop to do browser automation tasks.

# %% [markdown]
# ---
#
# ## Step 1
#
# ###  MCP Tools
#
# Resource Link: [Introducing More MCP Servers](https://github.com/punkpeye/awesome-mcp-servers) - This repository basically contains a curated list of MCP servers to explore.
#
# From my understanding, MCP is designed to extend the functionality of Large Language models. For example, a weather mpc is made available to a large language model. When the user ask about the weather, the llm decides whether it wants to call the weather tool, and leverage on MCP to provide accurate information.

# %% [markdown]
# ---
#
# ## Step 2
#
# I was able to Install Cline as an extension on Cursor. I had my Gemini Pro API key and used it to set up the LLM. While attempting to set up using Ollama, this was not possible as the system required more RAM resources than available.
#
# ### Screenshot
# ![Screenshot - Using Cline on cursor](./screenshots/Using%20Cline%20-%20Week%201%20Homework.png)

# %% [markdown]
# ---
#
# ## Step 3
#
# ### 1. Using Brave Search Tool
#
# Task: Search for “latest AI paper publication platforms” and list the top 3 search results with titles and URLs.
# Prompt in Claude: "**Use Brave Search to look up the latest AI paper publication platforms and return the top 3 results with title and link.**"
#
# #### Observations
#
# Claude was able to use the brave search search, using some sort of API and retrieved the 3 search results on the topic.
#
# #### Screenshot
#
# ![Screenshot](./screenshots/part1-step-3-claude.png)
#
#
# #### Example 2
#
# Task: ** Use brave search to look up the latest news articles in Kenya Today and list the top 5 with title, description, date published and source **
#
# #### Observations
#
# Some reqults failed to retrieve, I however got the results i needed after the brave search tool retried
#
# #### Screenshot 2
#
# ![Screenshot](./screenshots/part1-step-3-extra.png)
#
# ---
#
# ### 2. Github MCP
#
# Task: Access one of your public repositories (e.g., my-cool-project) and list the 5 most recent commits.
# Prompt in Claude:
#
# - "Connect to my GitHub account using the MCP plugin and list the 5 latest commits from the repository my-cool-project."
# - Prompt 2: "Connect to my github account using the github tool and list 5 lates commits from my most recent public repository"
#
# ### Observations
#
# - My first prompt was okay, I asked claude to visit a non existent repository and it did well.
# - My second prompt was vague, I asked Claude to pull up my latest repository's last 5 commits and it did that pretty well systematically retrieving the users, searching for the repositories, and then listing commits to the 5 most recent commits from the latest public repository.
#
#
# #### Screenshot
#
# ![Screenshot](./screenshots/part-1-github-tool.png)
#
# ---
#
# ### 3. Using Puppeteer.
#
# Task: Visit https://www.inference.ai/, take a full-page screenshot, and save it as example.png.
# Prompt in Claude:
# "Use Puppeteer to go to https://www.inference.ai/ and capture a full-page screenshot saved as example.png."
#
# #### Observations
#
# The puppeteer tool was able to retrieve the web page and display the image on the chat.
#
# #### Screenshot
#
# ![Screenshot](./screenshots/part-1-puppeteer.png)
#
# ---
#
# ### 4. File System MCP
#
# Task: Create a new folder on your Desktop named mcp_test, and inside it, create a text file hello.txt containing “Hello MCP!”.
# Prompt in Claude: "Use Filesystem to create a folder named mcp_test on my Desktop and add a file hello.txt inside with the text 'Hello MCP!'."
#
# #### Screenshot
#
# ![Screenshot](#)
#
# ---
#
# ### 5. Sequential Thinking
#
# Task: Think step-by-step about how to prepare for a technical interview and generate a preparation plan.
# Prompt in Claude:"Use Sequential Thinking to create a step-by-step plan for preparing for a technical interview."
#
# #### Screenshot
#
#
# ![Screenshot](#)
#
# ---
#
# ### 6.
#
# Task: Create a new Notion page titled “MCP Automation Test” and log the results of all the tasks above.
# Prompt in Claude: "Use the Notion plugin to create a new page titled 'MCP Automation Test' and write a summary of the tasks I just completed using each plugin."
#
# #### Screenshot
#
# ![Screenshot](#)
#
#
# ---
#
# ### 7. Advanced
#
# Advanced Task: Use Claude + Puppeteer to automatically visit a webpage, scrape table content, and save it locally (with the help of the Filesystem plugin).
# Project Management Workflow: Record the scraped and analyzed data into a Notion database, automatically generating documentation.
#
# #### Screenshot
#
# ![Screenshot](#)
